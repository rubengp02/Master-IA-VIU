# %%
s=50*'*'
print(s)
# Out:
# **************************************************

# %%
txt = 'Hola'

for c in txt:

   print(c)
# Out:
# H
# o
# l
# a

# %%
txt = 'Hola'
n=0
while n<len(txt):
    print(txt[n])
    n+=1
# Out:
# H
# o
# l
# a

# %%
d = {'mmar': 56, 'ougt': 10, 'dxbx': 59, 'qtlh': 87, 'wnsj': -46, 'ibnp': -171}
print(sum(d.values())/len(d))
# Out:
# -0.8333333333333334

# %%
lst=[['11111', 1322, 68], ['22222', 11213123, 32]]
print(sum(lst[:][1])/len(lst))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 lst=[['11111', 1322, 68], ['22222', 11213123, 32]]
# ----> 2 print(sum(lst[:][1])/len(lst))
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
if (a<100 or a>200) and a%2==1 and a%3==0:

# %%
print(3*30//60)
# Out:
# 1

# %%
dic=
dic[10]='Barcelona'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 dic[10]='Barcelona'
#
# NameError: name 'dic' is not defined

# %%
import pandas as pd
lst=[['1111A', 'Carlos', 68], ['1111A', 'Antonio', 78], ['1111A', 'Mari', 70], ['1111A', 'Juan', 90]]
col=['DNI', 'nombre', 'edad']
ind=['p1', 'p2', 'p3', 'p4']
dfPens=pd.DataFrame(lst, columns=col, index=ind)
dfPens.iloc[3, :].mean(axis=1)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import pandas as pd
#       2 lst=[['1111A', 'Carlos', 68], ['1111A', 'Antonio', 78], ['1111A', 'Mari', 70], ['1111A', 'Juan', 90]]
#       3 col=['DNI', 'nombre', 'edad']
#
# ModuleNotFoundError: No module named 'pandas'

# %%
print((3*30//60)+2)
# Out:
# 3
